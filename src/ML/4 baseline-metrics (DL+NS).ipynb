# %% [markdown]
# # **A Novel Approach for Three-Way Classification of Lumbar Spine Degeneration Using Pseudo-Modality Learning to Handle Missing MRI Data**

# %% [markdown]
# ## Libs

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.losses import BinaryCrossentropy
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score, roc_auc_score

# %% [markdown]
# ## Training Pipeline

# %%
def train(embedding_path, labels_path, loss_fn='binary_crossentropy', n_splits=5):
    embeddings = pd.read_csv(embedding_path)
    labels = pd.read_csv(labels_path)
    
    id_cols = labels[['study_id', 'series_id']]
    cols_to_impute = labels.drop(columns=['study_id', 'series_id'])
    imputed_cols = cols_to_impute.apply(lambda x: x.fillna(x.mode()[0]))
    final_df = pd.concat([id_cols, imputed_cols], axis=1)
    labels = final_df

    id_cols = labels[['study_id', 'series_id']]
    cols_to_encode = labels.drop(columns=['study_id', 'series_id'])
    encoder = OneHotEncoder(sparse_output=False)
    encoded_cols = encoder.fit_transform(cols_to_encode)
    encoded_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(cols_to_encode.columns))
    final_df = pd.concat([id_cols, encoded_df], axis=1)
    df = pd.merge(embeddings, final_df, on='study_id', how='inner')

    fc_layer = len(df.columns[515:])
    X = df.iloc[:, :512].values
    Y = df.iloc[:, 515:].values

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_accuracies = []
    fold_val_accuracies = []
    fold_f1_scores = []
    fold_roc_auc_scores = []
    
    best_test_accuracy = 0.0
    best_val_accuracy = 0.0

    for fold, (train_index, test_index) in enumerate(kf.split(X), 1):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        model = Sequential([
            Input(shape=(512,)),
            Dense(256, activation='relu'),
            Dense(128, activation='relu'),
            Dense(64, activation='relu'),
            Dense(fc_layer, activation='sigmoid')
        ])

        model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])
        history = model.fit(X_train, Y_train, epochs=20, batch_size=16, verbose=0, validation_data=(X_test, Y_test))

        loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
        fold_accuracies.append(accuracy)

        val_accuracy = np.mean(history.history['val_accuracy'])
        fold_val_accuracies.append(val_accuracy)

        # Predict on test set
        Y_pred = model.predict(X_test)

        # Calculate F1 Score and ROC AUC
        f1 = f1_score(Y_test, (Y_pred > 0.5).astype(int), average='macro', zero_division=1)
        
        if Y_test.sum(axis=0).min() == 0:
            print(f"Warning: Skipping ROC AUC for fold {fold} due to missing classes.")
            roc_auc = np.nan
        else:
            try:
                roc_auc = roc_auc_score(Y_test, Y_pred, average='macro', multi_class='ovr')
            except ValueError as e:
                print(f"Error calculating ROC AUC for fold {fold}: {e}.")
                roc_auc = np.nan

        fold_f1_scores.append(f1)
        fold_roc_auc_scores.append(roc_auc)

        if accuracy > best_test_accuracy:
            best_test_accuracy = accuracy
            best_val_accuracy = val_accuracy

        print(f'Fold {fold}: Test Accuracy = {accuracy:.4f}, Validation Accuracy = {val_accuracy:.4f}, '
              f'F1 Score = {f1:.4f}, ROC AUC = {roc_auc:.4f}')

    avg_accuracy = np.mean(fold_accuracies)
    avg_val_accuracy = np.mean(fold_val_accuracies)
    avg_f1_score = np.mean(fold_f1_scores)
    avg_roc_auc = np.mean(fold_roc_auc_scores)

    print(f'Average Test Accuracy across {n_splits} folds: {avg_accuracy:.4f}, '
          f'Average Validation Accuracy across {n_splits} folds: {avg_val_accuracy:.4f}, '
          f'Average F1 Score across {n_splits} folds: {avg_f1_score:.4f}, '
          f'Average ROC AUC across {n_splits} folds: {avg_roc_auc:.4f}')

    return avg_accuracy, avg_val_accuracy, best_test_accuracy, best_val_accuracy, avg_f1_score, avg_roc_auc

# %%
attention_embeddings_paths = [
    '/kaggle/input/attention-embeddings-for-rsna/AT2_attention_embeddings_gsl.csv',
    '/kaggle/input/attention-embeddings-for-rsna/AT2_attention_embeddings_hist.csv',
    '/kaggle/input/attention-embeddings-for-rsna/ST1_attention_embeddings_gsl.csv',
    '/kaggle/input/attention-embeddings-for-rsna/ST1_attention_embeddings_hist.csv',
    '/kaggle/input/attention-embeddings-for-rsna/ST2_attention_embeddings_gsl.csv',
    '/kaggle/input/attention-embeddings-for-rsna/ST2_attention_embeddings_hist.csv'    
]

average_embeddings_paths = [
    '/kaggle/input/embeddings-for-rsna/at2-greyscl/final_embeddings.csv',
    '/kaggle/input/embeddings-for-rsna/at2-hist/final_embeddings.csv',
    '/kaggle/input/embeddings-for-rsna/st1-greyscl/final_embeddings.csv',
    '/kaggle/input/embeddings-for-rsna/st1-hist/final_embeddings.csv',
    '/kaggle/input/embeddings-for-rsna/st2-greyscl/final_embeddings.csv',
    '/kaggle/input/embeddings-for-rsna/st2-hist/final_embeddings.csv'
]

medicalnet_embeddings_paths = [
    '/kaggle/input/medicalnet-attention-layers-for-rsna/AT2_attention_embeddings_gsl.csv',
    '/kaggle/input/medicalnet-attention-layers-for-rsna/AT2_attention_embeddings_hist.csv',
    '/kaggle/input/medicalnet-attention-layers-for-rsna/ST1_attention_embeddings_gsl.csv',
    '/kaggle/input/medicalnet-attention-layers-for-rsna/ST1_attention_embeddings_hist.csv',
    '/kaggle/input/medicalnet-attention-layers-for-rsna/ST2_attention_embeddings_gsl.csv',
    '/kaggle/input/medicalnet-attention-layers-for-rsna/ST2_attention_embeddings_hist.csv',
]

labels_paths = [
    '/kaggle/input/preprocessed-dataset/train_data_AT2.csv',
    '/kaggle/input/preprocessed-dataset/train_data_ST1.csv',
    '/kaggle/input/preprocessed-dataset/train_data_ST2.csv'
]

list_of_combination = [
    'AT2 - GSL - Attention Network',
    'AT2 - HIST - Attention Network',
    'ST1 - GSL - Attention Network',
    'ST1 - HIST - Attention Network',
    'ST2 - GSL - Attention Network',
    'ST2 - HIST - Attention Network',
    
    'AT2 - GSL - Average ResNet50',
    'AT2 - HIST - Average ResNet50',
    'ST1 - GSL - Average ResNet50',
    'ST1 - HIST - Average ResNet50',
    'ST2 - GSL - Average ResNet50',
    'ST2 - HIST - Average ResNet50',
    
    'AT2 - GSL - MedicalNet Network',
    'AT2 - HIST - MedicalNet Network',
    'ST1 - GSL - MedicalNet Network',
    'ST1 - HIST - MedicalNet Network',
    'ST2 - GSL - MedicalNet Network',
    'ST2 - HIST - MedicalNet Network'
]

results_df = pd.DataFrame(columns=['Combination', 'Avg_Test_Accuracy', 'Avg_Val_Accuracy'])

all_embedding_paths = [
    *attention_embeddings_paths,
    *average_embeddings_paths,
    *medicalnet_embeddings_paths
]

corresponding_labels_paths = [
    labels_paths[0],  # AT2 - GSL - Attention Network
    labels_paths[0],  # AT2 - HIST - Attention Network
    labels_paths[1],  # ST1 - GSL - Attention Network
    labels_paths[1],  # ST1 - HIST - Attention Network
    labels_paths[2],  # ST2 - GSL - Attention Network
    labels_paths[2],  # ST2 - HIST - Attention Network
    
    labels_paths[0],  # AT2 - GSL - Average ResNet50
    labels_paths[0],  # AT2 - HIST - Average ResNet50
    labels_paths[1],  # ST1 - GSL - Average ResNet50
    labels_paths[1],  # ST1 - HIST - Average ResNet50
    labels_paths[2],  # ST2 - GSL - Average ResNet50
    labels_paths[2],  # ST2 - HIST - Average ResNet50
    
    labels_paths[0],  # AT2 - GSL - MedicalNet Network
    labels_paths[0],  # AT2 - HIST - MedicalNet Network
    labels_paths[1],  # ST1 - GSL - MedicalNet Network
    labels_paths[1],  # ST1 - HIST - MedicalNet Network
    labels_paths[2],  # ST2 - GSL - MedicalNet Network
    labels_paths[2],  # ST2 - HIST - MedicalNet Network
]

# %%
results_df = pd.DataFrame(columns=['Combination', 'Avg_Test_Accuracy', 'Avg_Val_Accuracy', 'Best_Test_Accuracy', 'Best_Val_Accuracy', 'Avg_F1_Score', 'Avg_ROC_AUC'])

for embedding_path, label_path, name in zip(all_embedding_paths, corresponding_labels_paths, list_of_combination):
    print(f"\nTraining for: {name} - {embedding_path}")
    avg_accuracy, avg_val_accuracy, best_test_accuracy, best_val_accuracy, avg_f1_score, avg_roc_auc = train(embedding_path, label_path)
    
    result_row = pd.DataFrame({
        'Combination': [name],
        'Avg_Test_Accuracy': [avg_accuracy],
        'Avg_Val_Accuracy': [avg_val_accuracy],
        'Best_Test_Accuracy': [best_test_accuracy],
        'Best_Val_Accuracy': [best_val_accuracy],
        'Avg_F1_Score' : [avg_f1_score], 
        'Avg_ROC_AUC': [avg_roc_auc],
    })
    
    results_df = pd.concat([results_df, result_row], ignore_index=True)

print("\nFinal Results DataFrame:")
# Out:
# Training for: AT2 - GSL - Attention Network - /kaggle/input/attention-embeddings-for-rsna/AT2_attention_embeddings_gsl.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 1 due to missing classes.
# Fold 1: Test Accuracy = 0.2328, Validation Accuracy = 0.3526, F1 Score = 0.6685, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 2 due to missing classes.
# Fold 2: Test Accuracy = 0.2714, Validation Accuracy = 0.3071, F1 Score = 0.6835, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3: Test Accuracy = 0.3015, Validation Accuracy = 0.2141, F1 Score = 0.6907, ROC AUC = 0.8457
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 4 due to missing classes.
# Fold 4: Test Accuracy = 0.1591, Validation Accuracy = 0.2263, F1 Score = 0.7356, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 5: Test Accuracy = 0.2097, Validation Accuracy = 0.2801, F1 Score = 0.6693, ROC AUC = 0.8487
# Average Test Accuracy across 5 folds: 0.2349, Average Validation Accuracy across 5 folds: 0.2760, Average F1 Score across 5 folds: 0.6895, Average ROC AUC across 5 folds: nan
#
# Training for: AT2 - HIST - Attention Network - /kaggle/input/attention-embeddings-for-rsna/AT2_attention_embeddings_hist.csv
# /tmp/ipykernel_16/351575431.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, result_row], ignore_index=True)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 1 due to missing classes.
# Fold 1: Test Accuracy = 0.3869, Validation Accuracy = 0.3480, F1 Score = 0.6552, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 2 due to missing classes.
# Fold 2: Test Accuracy = 0.3049, Validation Accuracy = 0.2818, F1 Score = 0.6749, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3: Test Accuracy = 0.2513, Validation Accuracy = 0.3458, F1 Score = 0.6932, ROC AUC = 0.8443
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 4 due to missing classes.
# Fold 4: Test Accuracy = 0.2328, Validation Accuracy = 0.3564, F1 Score = 0.7201, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 5: Test Accuracy = 0.2164, Validation Accuracy = 0.1988, F1 Score = 0.6394, ROC AUC = 0.8105
# Average Test Accuracy across 5 folds: 0.2785, Average Validation Accuracy across 5 folds: 0.3062, Average F1 Score across 5 folds: 0.6766, Average ROC AUC across 5 folds: nan
#
# Training for: ST1 - GSL - Attention Network - /kaggle/input/attention-embeddings-for-rsna/ST1_attention_embeddings_gsl.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.2111, Validation Accuracy = 0.3191, F1 Score = 0.3621, ROC AUC = 0.6115
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.3773, Validation Accuracy = 0.3947, F1 Score = 0.3503, ROC AUC = 0.6216
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 3: Test Accuracy = 0.2507, Validation Accuracy = 0.3326, F1 Score = 0.3421, ROC AUC = 0.6214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 4: Test Accuracy = 0.2751, Validation Accuracy = 0.2569, F1 Score = 0.3649, ROC AUC = 0.6025
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 5: Test Accuracy = 0.3598, Validation Accuracy = 0.4148, F1 Score = 0.3617, ROC AUC = 0.6385
# Average Test Accuracy across 5 folds: 0.2948, Average Validation Accuracy across 5 folds: 0.3436, Average F1 Score across 5 folds: 0.3562, Average ROC AUC across 5 folds: 0.6191
#
# Training for: ST1 - HIST - Attention Network - /kaggle/input/attention-embeddings-for-rsna/ST1_attention_embeddings_hist.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.1662, Validation Accuracy = 0.3483, F1 Score = 0.3670, ROC AUC = 0.6160
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.3351, Validation Accuracy = 0.3207, F1 Score = 0.3567, ROC AUC = 0.6145
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 3: Test Accuracy = 0.3298, Validation Accuracy = 0.3697, F1 Score = 0.3511, ROC AUC = 0.6408
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.2540, Validation Accuracy = 0.3602, F1 Score = 0.3691, ROC AUC = 0.6148
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.3254, Validation Accuracy = 0.4422, F1 Score = 0.3685, ROC AUC = 0.6530
# Average Test Accuracy across 5 folds: 0.2821, Average Validation Accuracy across 5 folds: 0.3682, Average F1 Score across 5 folds: 0.3625, Average ROC AUC across 5 folds: 0.6278
#
# Training for: ST2 - GSL - Attention Network - /kaggle/input/attention-embeddings-for-rsna/ST2_attention_embeddings_gsl.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.2952, Validation Accuracy = 0.3254, F1 Score = 0.3380, ROC AUC = 0.6589
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.2880, Validation Accuracy = 0.3283, F1 Score = 0.3254, ROC AUC = 0.6083
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Warning: Skipping ROC AUC for fold 3 due to missing classes.
# Fold 3: Test Accuracy = 0.3280, Validation Accuracy = 0.3525, F1 Score = 0.3457, ROC AUC = nan
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.1707, Validation Accuracy = 0.2657, F1 Score = 0.3455, ROC AUC = 0.6220
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 5: Test Accuracy = 0.4373, Validation Accuracy = 0.3095, F1 Score = 0.3550, ROC AUC = 0.6437
# Average Test Accuracy across 5 folds: 0.3038, Average Validation Accuracy across 5 folds: 0.3163, Average F1 Score across 5 folds: 0.3419, Average ROC AUC across 5 folds: nan
#
# Training for: ST2 - HIST - Attention Network - /kaggle/input/attention-embeddings-for-rsna/ST2_attention_embeddings_hist.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 1: Test Accuracy = 0.3112, Validation Accuracy = 0.2738, F1 Score = 0.3463, ROC AUC = 0.6754
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 2: Test Accuracy = 0.2213, Validation Accuracy = 0.2839, F1 Score = 0.3466, ROC AUC = 0.6285
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Warning: Skipping ROC AUC for fold 3 due to missing classes.
# Fold 3: Test Accuracy = 0.2507, Validation Accuracy = 0.2668, F1 Score = 0.4106, ROC AUC = nan
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.2800, Validation Accuracy = 0.3315, F1 Score = 0.3365, ROC AUC = 0.6381
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.2613, Validation Accuracy = 0.2955, F1 Score = 0.3349, ROC AUC = 0.6069
# Average Test Accuracy across 5 folds: 0.2649, Average Validation Accuracy across 5 folds: 0.2903, Average F1 Score across 5 folds: 0.3550, Average ROC AUC across 5 folds: nan
#
# Training for: AT2 - GSL - Average ResNet50 - /kaggle/input/embeddings-for-rsna/at2-greyscl/final_embeddings.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 1 due to missing classes.
# Fold 1: Test Accuracy = 0.5645, Validation Accuracy = 0.6351, F1 Score = 0.4296, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 2 due to missing classes.
# Fold 2: Test Accuracy = 0.3300, Validation Accuracy = 0.5153, F1 Score = 0.4224, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3: Test Accuracy = 0.5025, Validation Accuracy = 0.5540, F1 Score = 0.3661, ROC AUC = 0.7469
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 4 due to missing classes.
# Fold 4: Test Accuracy = 0.5762, Validation Accuracy = 0.5191, F1 Score = 0.4431, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 5: Test Accuracy = 0.3809, Validation Accuracy = 0.4997, F1 Score = 0.4025, ROC AUC = 0.7647
# Average Test Accuracy across 5 folds: 0.4708, Average Validation Accuracy across 5 folds: 0.5446, Average F1 Score across 5 folds: 0.4127, Average ROC AUC across 5 folds: nan
#
# Training for: AT2 - HIST - Average ResNet50 - /kaggle/input/embeddings-for-rsna/at2-hist/final_embeddings.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 1 due to missing classes.
# Fold 1: Test Accuracy = 0.5226, Validation Accuracy = 0.5365, F1 Score = 0.4741, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 2 due to missing classes.
# Fold 2: Test Accuracy = 0.3953, Validation Accuracy = 0.5802, F1 Score = 0.4504, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3: Test Accuracy = 0.4422, Validation Accuracy = 0.4866, F1 Score = 0.5366, ROC AUC = 0.7584
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 4 due to missing classes.
# Fold 4: Test Accuracy = 0.4975, Validation Accuracy = 0.5609, F1 Score = 0.4769, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 5: Test Accuracy = 0.4715, Validation Accuracy = 0.5302, F1 Score = 0.4606, ROC AUC = 0.7740
# Average Test Accuracy across 5 folds: 0.4658, Average Validation Accuracy across 5 folds: 0.5389, Average F1 Score across 5 folds: 0.4797, Average ROC AUC across 5 folds: nan
#
# Training for: ST1 - GSL - Average ResNet50 - /kaggle/input/embeddings-for-rsna/st1-greyscl/final_embeddings.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.4011, Validation Accuracy = 0.5653, F1 Score = 0.2768, ROC AUC = 0.6041
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 2: Test Accuracy = 0.5488, Validation Accuracy = 0.5967, F1 Score = 0.2721, ROC AUC = 0.5930
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 3: Test Accuracy = 0.5989, Validation Accuracy = 0.5774, F1 Score = 0.2736, ROC AUC = 0.5806
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.3386, Validation Accuracy = 0.4409, F1 Score = 0.2715, ROC AUC = 0.5446
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 5: Test Accuracy = 0.4392, Validation Accuracy = 0.4974, F1 Score = 0.2922, ROC AUC = 0.5539
# Average Test Accuracy across 5 folds: 0.4653, Average Validation Accuracy across 5 folds: 0.5355, Average F1 Score across 5 folds: 0.2773, Average ROC AUC across 5 folds: 0.5752
#
# Training for: ST1 - HIST - Average ResNet50 - /kaggle/input/embeddings-for-rsna/st1-hist/final_embeddings.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 1: Test Accuracy = 0.3958, Validation Accuracy = 0.4760, F1 Score = 0.2971, ROC AUC = 0.6271
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 2: Test Accuracy = 0.5330, Validation Accuracy = 0.5839, F1 Score = 0.3128, ROC AUC = 0.6140
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 3: Test Accuracy = 0.5673, Validation Accuracy = 0.5391, F1 Score = 0.3023, ROC AUC = 0.5927
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 4: Test Accuracy = 0.3915, Validation Accuracy = 0.5549, F1 Score = 0.3056, ROC AUC = 0.5763
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 5: Test Accuracy = 0.3439, Validation Accuracy = 0.4652, F1 Score = 0.3131, ROC AUC = 0.5914
# Average Test Accuracy across 5 folds: 0.4463, Average Validation Accuracy across 5 folds: 0.5238, Average F1 Score across 5 folds: 0.3062, Average ROC AUC across 5 folds: 0.6003
#
# Training for: ST2 - GSL - Average ResNet50 - /kaggle/input/embeddings-for-rsna/st2-greyscl/final_embeddings.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.6383, Validation Accuracy = 0.5769, F1 Score = 0.3289, ROC AUC = 0.6730
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.2747, Validation Accuracy = 0.4536, F1 Score = 0.3429, ROC AUC = 0.6534
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Warning: Skipping ROC AUC for fold 3 due to missing classes.
# Fold 3: Test Accuracy = 0.5707, Validation Accuracy = 0.4480, F1 Score = 0.3792, ROC AUC = nan
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.6507, Validation Accuracy = 0.5423, F1 Score = 0.3330, ROC AUC = 0.6710
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.7147, Validation Accuracy = 0.4553, F1 Score = 0.3225, ROC AUC = 0.6306
# Average Test Accuracy across 5 folds: 0.5698, Average Validation Accuracy across 5 folds: 0.4952, Average F1 Score across 5 folds: 0.3413, Average ROC AUC across 5 folds: nan
#
# Training for: ST2 - HIST - Average ResNet50 - /kaggle/input/embeddings-for-rsna/st2-hist/final_embeddings.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 1: Test Accuracy = 0.5612, Validation Accuracy = 0.5257, F1 Score = 0.3347, ROC AUC = 0.5948
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.4773, Validation Accuracy = 0.4859, F1 Score = 0.3334, ROC AUC = 0.6295
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Warning: Skipping ROC AUC for fold 3 due to missing classes.
# Fold 3: Test Accuracy = 0.5387, Validation Accuracy = 0.5008, F1 Score = 0.4148, ROC AUC = nan
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 4: Test Accuracy = 0.3707, Validation Accuracy = 0.5387, F1 Score = 0.3278, ROC AUC = 0.6859
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.4773, Validation Accuracy = 0.5083, F1 Score = 0.3250, ROC AUC = 0.6216
# Average Test Accuracy across 5 folds: 0.4850, Average Validation Accuracy across 5 folds: 0.5119, Average F1 Score across 5 folds: 0.3472, Average ROC AUC across 5 folds: nan
#
# Training for: AT2 - GSL - MedicalNet Network - /kaggle/input/medicalnet-attention-layers-for-rsna/AT2_attention_embeddings_gsl.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 1 due to missing classes.
# Fold 1: Test Accuracy = 0.4322, Validation Accuracy = 0.5482, F1 Score = 0.3348, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 2 due to missing classes.
# Fold 2: Test Accuracy = 0.6097, Validation Accuracy = 0.5457, F1 Score = 0.3726, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3: Test Accuracy = 0.1910, Validation Accuracy = 0.5816, F1 Score = 0.3267, ROC AUC = 0.6052
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 4 due to missing classes.
# Fold 4: Test Accuracy = 0.8660, Validation Accuracy = 0.6591, F1 Score = 0.3306, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 5: Test Accuracy = 0.7466, Validation Accuracy = 0.5701, F1 Score = 0.3219, ROC AUC = 0.5912
# Average Test Accuracy across 5 folds: 0.5691, Average Validation Accuracy across 5 folds: 0.5809, Average F1 Score across 5 folds: 0.3373, Average ROC AUC across 5 folds: nan
#
# Training for: AT2 - HIST - MedicalNet Network - /kaggle/input/medicalnet-attention-layers-for-rsna/AT2_attention_embeddings_hist.csv
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 1 due to missing classes.
# Fold 1: Test Accuracy = 0.6583, Validation Accuracy = 0.6686, F1 Score = 0.3420, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 2 due to missing classes.
# Fold 2: Test Accuracy = 0.4154, Validation Accuracy = 0.5133, F1 Score = 0.3675, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3: Test Accuracy = 0.4573, Validation Accuracy = 0.5662, F1 Score = 0.3849, ROC AUC = 0.6094
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Warning: Skipping ROC AUC for fold 4 due to missing classes.
# Fold 4: Test Accuracy = 0.4355, Validation Accuracy = 0.6642, F1 Score = 0.3845, ROC AUC = nan
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 5: Test Accuracy = 0.7567, Validation Accuracy = 0.6180, F1 Score = 0.3528, ROC AUC = 0.5988
# Average Test Accuracy across 5 folds: 0.5446, Average Validation Accuracy across 5 folds: 0.6060, Average F1 Score across 5 folds: 0.3663, Average ROC AUC across 5 folds: nan
#
# Training for: ST1 - GSL - MedicalNet Network - /kaggle/input/medicalnet-attention-layers-for-rsna/ST1_attention_embeddings_gsl.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.4828, Validation Accuracy = 0.5346, F1 Score = 0.2875, ROC AUC = 0.5820
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.6623, Validation Accuracy = 0.6459, F1 Score = 0.2864, ROC AUC = 0.5668
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 3: Test Accuracy = 0.5409, Validation Accuracy = 0.5749, F1 Score = 0.2873, ROC AUC = 0.5612
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.6270, Validation Accuracy = 0.4950, F1 Score = 0.2782, ROC AUC = 0.5364
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.6667, Validation Accuracy = 0.6037, F1 Score = 0.2997, ROC AUC = 0.5509
# Average Test Accuracy across 5 folds: 0.5959, Average Validation Accuracy across 5 folds: 0.5708, Average F1 Score across 5 folds: 0.2878, Average ROC AUC across 5 folds: 0.5595
#
# Training for: ST1 - HIST - MedicalNet Network - /kaggle/input/medicalnet-attention-layers-for-rsna/ST1_attention_embeddings_hist.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.5673, Validation Accuracy = 0.6016, F1 Score = 0.2825, ROC AUC = 0.5533
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 2: Test Accuracy = 0.4565, Validation Accuracy = 0.5459, F1 Score = 0.3015, ROC AUC = 0.5275
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 3: Test Accuracy = 0.5356, Validation Accuracy = 0.5698, F1 Score = 0.3061, ROC AUC = 0.5875
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 4: Test Accuracy = 0.6958, Validation Accuracy = 0.5390, F1 Score = 0.2940, ROC AUC = 0.5542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.4841, Validation Accuracy = 0.4647, F1 Score = 0.3038, ROC AUC = 0.5491
# Average Test Accuracy across 5 folds: 0.5479, Average Validation Accuracy across 5 folds: 0.5442, Average F1 Score across 5 folds: 0.2976, Average ROC AUC across 5 folds: 0.5543
#
# Training for: ST2 - GSL - MedicalNet Network - /kaggle/input/medicalnet-attention-layers-for-rsna/ST2_attention_embeddings_gsl.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.3644, Validation Accuracy = 0.4580, F1 Score = 0.3152, ROC AUC = 0.5780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.1627, Validation Accuracy = 0.2393, F1 Score = 0.3206, ROC AUC = 0.5196
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Warning: Skipping ROC AUC for fold 3 due to missing classes.
# Fold 3: Test Accuracy = 0.5413, Validation Accuracy = 0.4824, F1 Score = 0.3908, ROC AUC = nan
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 4: Test Accuracy = 0.3600, Validation Accuracy = 0.4617, F1 Score = 0.3117, ROC AUC = 0.5581
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.0853, Validation Accuracy = 0.4636, F1 Score = 0.3169, ROC AUC = 0.5852
# Average Test Accuracy across 5 folds: 0.3027, Average Validation Accuracy across 5 folds: 0.4210, Average F1 Score across 5 folds: 0.3310, Average ROC AUC across 5 folds: nan
#
# Training for: ST2 - HIST - MedicalNet Network - /kaggle/input/medicalnet-attention-layers-for-rsna/ST2_attention_embeddings_hist.csv
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 1: Test Accuracy = 0.1968, Validation Accuracy = 0.3168, F1 Score = 0.3114, ROC AUC = 0.5704
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 2: Test Accuracy = 0.2427, Validation Accuracy = 0.2516, F1 Score = 0.3161, ROC AUC = 0.5212
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Warning: Skipping ROC AUC for fold 3 due to missing classes.
# Fold 3: Test Accuracy = 0.3813, Validation Accuracy = 0.4757, F1 Score = 0.3779, ROC AUC = nan
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 4: Test Accuracy = 0.5307, Validation Accuracy = 0.4679, F1 Score = 0.3201, ROC AUC = 0.5143
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Fold 5: Test Accuracy = 0.3120, Validation Accuracy = 0.3907, F1 Score = 0.3187, ROC AUC = 0.5619
# Average Test Accuracy across 5 folds: 0.3327, Average Validation Accuracy across 5 folds: 0.3805, Average F1 Score across 5 folds: 0.3288, Average ROC AUC across 5 folds: nan
#
# Final Results DataFrame:

# %%
results_df
# Out:
#                         Combination  Avg_Test_Accuracy  Avg_Val_Accuracy  \
# 0     AT2 - GSL - Attention Network           0.234911          0.276040
# 1    AT2 - HIST - Attention Network           0.278464          0.306164
# 2     ST1 - GSL - Attention Network           0.294794          0.343626
# 3    ST1 - HIST - Attention Network           0.282100          0.368207
# 4     ST2 - GSL - Attention Network           0.303843          0.316280
# 5    ST2 - HIST - Attention Network           0.264901          0.290281
# 6      AT2 - GSL - Average ResNet50           0.470814          0.544640
# 7     AT2 - HIST - Average ResNet50           0.465820          0.538888
# 8      ST1 - GSL - Average ResNet50           0.465318          0.535535
# 9     ST1 - HIST - Average ResNet50           0.446298          0.523810
# 10     ST2 - GSL - Average ResNet50           0.569793          0.495212
# 11    ST2 - HIST - Average ResNet50           0.485034          0.511853
# 12   AT2 - GSL - MedicalNet Network           0.569094          0.580928
# 13  AT2 - HIST - MedicalNet Network           0.544642          0.606036
# 14   ST1 - GSL - MedicalNet Network           0.595933          0.570817
# 15  ST1 - HIST - MedicalNet Network           0.547852          0.544197
# 16   ST2 - GSL - MedicalNet Network           0.302739          0.421009
# 17  ST2 - HIST - MedicalNet Network           0.332695          0.380524
#
#     Best_Test_Accuracy  Best_Val_Accuracy  Avg_F1_Score  Avg_ROC_AUC
# 0             0.301508           0.214070      0.689527          NaN
# 1             0.386935           0.347990      0.676578          NaN
# 2             0.377309           0.394723      0.356223     0.619086
# 3             0.335092           0.320712      0.362480     0.627817
# 4             0.437333           0.309467      0.341935          NaN
# 5             0.311170           0.273803      0.354975          NaN
# 6             0.576214           0.519095      0.412726          NaN
# 7             0.522613           0.536516      0.479706          NaN
# 8             0.598945           0.577441      0.277259     0.575243
# 9             0.567282           0.539050      0.306173     0.600305
# 10            0.714667           0.455333      0.341304          NaN
# 11            0.561170           0.525665      0.347156          NaN
# 12            0.865997           0.659129      0.337319          NaN
# 13            0.756711           0.617953      0.366315          NaN
# 14            0.666667           0.603704      0.287818     0.559470
# 15            0.695767           0.539021      0.297563     0.554294
# 16            0.541333           0.482400      0.331042          NaN
# 17            0.530667           0.467867      0.328813          NaN

# %%
def random_predictions(path):
    labels = pd.read_csv(path)

    id_cols = labels[['study_id', 'series_id']]
    cols_to_impute = labels.drop(columns=['study_id', 'series_id'])
    imputed_cols = cols_to_impute.apply(lambda x: x.fillna(x.mode()[0]))
    final_df = pd.concat([id_cols, imputed_cols], axis=1)

    id_cols = final_df[['study_id', 'series_id']]
    cols_to_encode = final_df.drop(columns=['study_id', 'series_id'])
    encoder = OneHotEncoder(sparse_output=False)
    encoded_cols = encoder.fit_transform(cols_to_encode)
    encoded_df = pd.DataFrame(encoded_cols, columns=encoder.get_feature_names_out(cols_to_encode.columns))
    final_df = pd.concat([id_cols, encoded_df], axis=1)

    Y_true = final_df.drop(columns=['study_id', 'series_id']).values

    np.random.seed(42)  # For reproducibility
    random_predictions = np.random.rand(*Y_true.shape)  # Random floats in [0.0, 1.0]

    threshold = np.mean(random_predictions)

    binary_predictions = (random_predictions > threshold).astype(float)

    accuracy = np.mean(np.all(binary_predictions == Y_true, axis=1))

    print(f"Random Predictions Accuracy: {accuracy:.4f}")
    print(f"Self-adjusting Threshold: {threshold:.4f}")

# %% [markdown]
# ## Random Accuracy

# %%
random_predictions('/kaggle/input/preprocessed-dataset/train_data_AT2.csv')
random_predictions('/kaggle/input/preprocessed-dataset/train_data_ST1.csv')
random_predictions('/kaggle/input/preprocessed-dataset/train_data_ST2.csv')
# Out:
# Random Predictions Accuracy: 0.0000
# Self-adjusting Threshold: 0.4996
# Random Predictions Accuracy: 0.0000
# Self-adjusting Threshold: 0.4995
# Random Predictions Accuracy: 0.0000
# Self-adjusting Threshold: 0.5004
